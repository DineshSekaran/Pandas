# %%
# Ref https://github.com/justmarkham
#Read tabular data file into Pandas
It looks like table which columns and row.File like csv,etc

# %%
import pandas as pd

# %%
#read_table by deafult Tab separater we can use 
pd.read_csv('http://bit.ly/chiporders',sep='\t')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
pd.read_table('http://bit.ly/chiporders',sep='\t')
# Out:
# C:\Users\Dinesh Sekaran\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# ...

# %%
orders=pd.read_csv('http://bit.ly/chiporders',sep='\t')

# %%
orders.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
pd.read_table('http://bit.ly/movieusers')
# Out:
# C:\Users\Dinesh Sekaran\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# 5      7|57|M|administrator|91344
# 6      8|36|M|administrator|05201
# 7            9|29|M|student|01002
# 8            10|53|M|lawyer|90703
# 9             11|39|F|other|30329
# 10            12|28|F|other|06405
# 11         13|47|M|educator|29206
# 12        14|45|M|scientist|55106
# 13         15|49|F|educator|97301
# 14    16|21|M|entertainment|10309
# 15       17|30|M|programmer|06355
# 16            18|35|F|other|37212
# 17        19|40|M|librarian|02138
# 18        20|42|F|homemaker|95660
# 19           21|26|M|writer|30068
# ...

# %%
# Adding Header columns and giving name from list below

# %%
pd.read_table('http://bit.ly/movieusers',sep='|',header=None)
# Out:
# C:\Users\Dinesh Sekaran\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# 5      6  42  M      executive  98101
# 6      7  57  M  administrator  91344
# 7      8  36  M  administrator  05201
# 8      9  29  M        student  01002
# 9     10  53  M         lawyer  90703
# 10    11  39  F          other  30329
# 11    12  28  F          other  06405
# 12    13  47  M       educator  29206
# 13    14  45  M      scientist  55106
# 14    15  49  F       educator  97301
# 15    16  21  M  entertainment  10309
# 16    17  30  M     programmer  06355
# 17    18  35  F          other  37212
# 18    19  40  M      librarian  02138
# ...

# %%
user_cols=['user_id','age','Sex','Occupation','code']
user=pd.read_table('http://bit.ly/movieusers',sep='|',names=user_cols)
# Out:
# C:\Users\Dinesh Sekaran\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.

# %%
user.head(5)
# Out:
#    user_id  age Sex  Occupation   code
# 0        1   24   M  technician  85711
# 1        2   53   F       other  94043
# 2        3   23   M      writer  32067
# 3        4   24   M  technician  43537
# 4        5   33   F       other  15213

# %%
# Select Pandas Series from DataFrame

# %%
ufo=pd.read_table("http://bit.ly/uforeports")
# Out:
# C:\Users\Dinesh Sekaran\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
ufo.head()
# Out:
#    City,Colors Reported,Shape Reported,State,Time
# 0              Ithaca,,TRIANGLE,NY,6/1/1930 22:00
# 1           Willingboro,,OTHER,NJ,6/30/1930 20:00
# 2                Holyoke,,OVAL,CO,2/15/1931 14:00
# 3                 Abilene,,DISK,KS,6/1/1931 13:00
# 4  New York Worlds Fair,,LIGHT,NY,4/18/1933 19:00

# %%
ufo=pd.read_table("http://bit.ly/uforeports",sep=',')
# Out:
# C:\Users\Dinesh Sekaran\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
type(ufo['City'])
# Out:
# pandas.core.series.Series

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
type(ufo.City)
# Out:
# pandas.core.series.Series

# %%
# Total Rows and Columns
ufo.shape
# Out:
# (18241, 5)

# %%
#Python String
'ab'+'cd'
# Out:
# 'abcd'

# %%
#Create new column in data frame with Brackets notation
ufo['Loc']=ufo.City+'-'+ufo.State

# %%
ufo.head(2)
# Out:
#           City Colors Reported Shape Reported State             Time  \
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
#
#               Loc
# 0       Ithaca-NY
# 1  Willingboro-NJ

# %%
# Pandas ends with Parenthesis and others commands not

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head(3)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
#Script statistics
# its Method
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
#Returns as tuple values
# Its attributes
movies.shape
# Out:
# (979, 6)

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# DataFrame have method and attributes
#Method are action oreineted
#Attributes are just like describe 
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
#movies is an object
movies.describe(include=['object'])
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
#Shit Tab on movies.describe(include=['object'])

Signature: movies.describe(percentiles=None, include=None, exclude=None)
Docstring:
Generate descriptive statistics that summarize the central tendency,
dispersion and shape of a dataset's distribution, excluding
``NaN`` values.

Analyzes both numeric and object series, as well
as ``DataFrame`` column sets of mixed data types. The output
will vary depending on what is provided. Refer to the notes
below for more detail.

Parameters
----------
percentiles : list-like of numbers, optional
    The percentiles to include in the output. All should
    fall between 0 and 1. The default is
    ``[.25, .5, .75]``, which returns the 25th, 50th, and
    75th percentiles.
include : 'all', list-like of dtypes or None (default), optional
    A white list of data types to include in the result. Ignored
    for ``Series``. Here are the options:

    - 'all' : All columns of the input will be included in the output.
    - A list-like of dtypes : Limits the results to the
      provided data types.
      To limit the result to numeric types submit
      ``numpy.number``. To limit it instead to object columns submit
      the ``numpy.object`` data type. Strings
      can also be used in the style of
      ``select_dtypes`` (e.g. ``df.describe(include=['O'])``). To
      select pandas categorical columns, use ``'category'``
    - None (default) : The result will include all numeric columns.
exclude : list-like of dtypes or None (default), optional,
    A black list of data types to omit from the result. Ignored
    for ``Series``. Here are the options:

    - A list-like of dtypes : Excludes the provided data types
      from the result. To exclude numeric types submit
      ``numpy.number``. To exclude object columns submit the data
      type ``numpy.object``. Strings can also be used in the style of
      ``select_dtypes`` (e.g. ``df.describe(include=['O'])``). To
      exclude pandas categorical columns, use ``'category'``
    - None (default) : The result will exclude nothing.

# %%
# Rename columns in Pandas DataFrame

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head(1)
# Out:
#      City Colors Reported Shape Reported State            Time
# 0  Ithaca             NaN       TRIANGLE    NY  6/1/1930 22:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.rename(columns={'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'},inplace=True)

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
ufo_cols=['city','colors reported','shape reproted','state','time']

# %%
# Assign value
ufo.columns=ufo_cols

# %%
ufo.columns
# Out:
# Index(['city', 'colors reported', 'shape reproted', 'state', 'time'], dtype='object')

# %%
ufo.head(2)
# Out:
#           city colors reported shape reproted state             time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
#Rename column name while reaing Files
ufo=pd.read_csv('http://bit.ly/uforeports',names=ufo_cols,header=0)

# %%
ufo.head(2)
# Out:
#           city colors reported shape reproted state             time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
ufo.columns
# Out:
# Index(['city', 'colors reported', 'shape reproted', 'state', 'time'], dtype='object')

# %%
ufo.columns=ufo.columns.str.replace(' ','_')

# %%
ufo.columns
# Out:
# Index(['city', 'colors_reported', 'shape_reproted', 'state', 'time'], dtype='object')

# %%
# Remove Columns from Pandas Data Frame

# %%
r=pd.read_csv('http://bit.ly/uforeports')

# %%
r.tail(2)
# Out:
#               City Colors Reported Shape Reported State              Time
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
r.shape
# Out:
# (18241, 5)

# %%
r.drop('Colors Reported',axis=1,inplace=True)

# %%
r.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
r.drop(['City','State'],axis=1,inplace=True)

# %%
# Rows 0 are nothing but index,Label
r.head()
# Out:
#   Shape Reported             Time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %%
# Remove Rows use axis=0
r.drop([0,1],axis=0,inplace=True)

# %%
r.head()
# Out:
#   Shape Reported             Time
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00
# 5           DISK  9/15/1934 15:30
# 6         CIRCLE   6/15/1935 0:00

# %%
# COunt reduced by 2
r.shape
# Out:
# (18239, 2)

# %%
# Sort Pandas Data Frame and Series

# %%
s=pd.read_csv('http://bit.ly/imdbratings')

# %%
s
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
# Sort by Data Frame using .notation
s.title.sort_values()
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
type(s['title'].sort_values())
# Out:
# pandas.core.series.Series

# %%
# Otherway
#s.sort_values('title')
s['title'].sort_values(ascending=False)
# Out:
# 864                                  [Rec]
# 526                                   Zulu
# 615                             Zombieland
# 677                                 Zodiac
# 955                       Zero Dark Thirty
# 535                                  Zelig
# 280                     Young Frankenstein
# 96                                 Yojimbo
# 235                                Yip Man
# 403                             Ying xiong
# 695                      Y Tu Mama Tambien
# 871                                     X2
# 532                     X-Men: First Class
# 248             X-Men: Days of Future Past
# 954                                  X-Men
# 518                         Wreck-It Ralph
# 970                            Wonder Boys
# 65             Witness for the Prosecution
# 920                                Witness
# 483                           Withnail & I
# 270                        Wings of Desire
# 497    Willy Wonka & the Chocolate Factory
# ...

# %%
# Multiple columns sorting
s.sort_values(['content_rating','duration'])
# Out:
#      star_rating                               title content_rating  \
# 713          7.6                     The Jungle Book       APPROVED
# 513          7.8      Invasion of the Body Snatchers       APPROVED
# 272          8.1                         The Killing       APPROVED
# 703          7.6                             Dracula       APPROVED
# 612          7.7                  A Hard Day's Night       APPROVED
# 58           8.5                      Paths of Glory       APPROVED
# 210          8.1                               Laura       APPROVED
# 656          7.7     Snow White and the Seven Dwarfs       APPROVED
# 844          7.5                           Pinocchio       APPROVED
# 233          8.1             The Night of the Hunter       APPROVED
# 287          8.1                     His Girl Friday       APPROVED
# 484          7.8       The Day the Earth Stood Still       APPROVED
# 451          7.9              Miracle on 34th Street       APPROVED
# ...

# %%
# Filter Pandas Data Frame

# %%
import pandas as pd
f_movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
f_movies.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
bool_list_movies=[]
for i in f_movies.duration:
    if i >=200:
        bool_list_movies.append(True)
    else:
        bool_list_movies.append(False)

# %%
is_long=pd.Series(bool_list_movies)

# %%
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
f_movies[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
#other method
is_long_d=f_movies.duration>=200

# %%
is_long_d.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: duration, dtype: bool

# %%
f_movies[is_long_d]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
#other method
is_long_rating=f_movies.content_rating=='R'

# %%
f_movies[is_long_rating].head()
# Out:
#    star_rating                     title content_rating      genre  duration  \
# 0          9.3  The Shawshank Redemption              R      Crime       142
# 1          9.2             The Godfather              R      Crime       175
# 2          9.1    The Godfather: Part II              R      Crime       200
# 4          8.9              Pulp Fiction              R      Crime       154
# 8          8.9          Schindler's List              R  Biography       195
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 8  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...

# %%
cols=['star_rating','title']
f_movies[is_long_rating][cols]
# Out:
#      star_rating                            title
# 0            9.3         The Shawshank Redemption
# 1            9.2                    The Godfather
# 2            9.1           The Godfather: Part II
# 4            8.9                     Pulp Fiction
# 8            8.9                 Schindler's List
# 9            8.9                       Fight Club
# 16           8.7  One Flew Over the Cuckoo's Nest
# 18           8.7                       Goodfellas
# 20           8.7                       The Matrix
# 21           8.7                      City of God
# 23           8.7               The Usual Suspects
# 24           8.7                            Se7en
# 27           8.6         The Silence of the Lambs
# 28           8.6           Leon: The Professional
# 31           8.6                 The Intouchables
# 33           8.6                         Whiplash
# 34           8.6               American History X
# 36           8.6              Saving Private Ryan
# ...

# %%
#other method
is_long_not_rating=f_movies.content_rating!='R'
f_movies[is_long_not_rating]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 17           8.7                                      Seven Samurai
# 19           8.7                                          Star Wars
# 22           8.7                              It's a Wonderful Life
# ...

# %%
# Multiple Filter in Pandas on Data Frame
Logical Operator
AND &
OR |
# Out:
#   File "<ipython-input-81-7be8a7fb55f4>", line 2
#     Logical Operator
#                    ^
# SyntaxError: invalid syntax

# %%
filter_movies=pd.read_csv('http://bit.ly/imdbratings')

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
filter_movies[(filter_movies.duration>=200) & (filter_movies.genre=='Drama') ]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
(filter_movies.duration>=200) & (filter_movies.genre=='Drama')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
filter_movies[(filter_movies.genre=='Crime') | (filter_movies.genre=='Drama') ].head(6)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
# 4          8.9              Pulp Fiction              R  Crime       154
# 5          8.9              12 Angry Men      NOT RATED  Drama        96
# 9          8.9                Fight Club              R  Drama       139
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 9  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...

# %%
filter_movies[filter_movies.genre.isin(['Crime','Drama','Action'])].head(7)
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
# 5          8.9              12 Angry Men      NOT RATED   Drama        96
# 9          8.9                Fight Club              R   Drama       139
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# ...

# %%
# Select listed columns
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo=pd.read_csv('http://bit.ly/uforeports',usecols=['City','State'])

# %%
ufo.head()
# Out:
#                    City State
# 0                Ithaca    NY
# 1           Willingboro    NJ
# 2               Holyoke    CO
# 3               Abilene    KS
# 4  New York Worlds Fair    NY

# %%
ufo=pd.read_csv('http://bit.ly/uforeports',usecols=[0,4])

# %%
ufo.columns
# Out:
# Index(['City', 'Time'], dtype='object')

# %%
ufo.head()
# Out:
#                    City             Time
# 0                Ithaca   6/1/1930 22:00
# 1           Willingboro  6/30/1930 20:00
# 2               Holyoke  2/15/1931 14:00
# 3               Abilene   6/1/1931 13:00
# 4  New York Worlds Fair  4/18/1933 19:00

# %%
# CSV fatest and limit rows

# %%
ufo=pd.read_csv('http://bit.ly/uforeports',nrows=2)

# %%
ufo
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00

# %%
for c in ufo.City:
    print(c)
# Out:
# Ithaca
# Willingboro

# %%
for index,row in ufo.iterrows():
    print(index,row.City,'-',row.State)
# Out:
# 0 Ithaca - NY
# 1 Willingboro - NJ

# %%
#Best way to drop non numeric column

# %%
import pandas as pd
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
import numpy as np
drink=drinks.select_dtypes(include=[np.number]).dtypes

# %%
drink
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
drinks.tail(2)
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 191    Zambia             32               19              4
# 192  Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 191                           2.5    Africa
# 192                           4.7    Africa

# %%
#Describe takes only Number
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe(include='all')
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# count      193     193.000000       193.000000     193.000000
# unique     193            NaN              NaN            NaN
# top     Kuwait            NaN              NaN            NaN
# freq         1            NaN              NaN            NaN
# mean       NaN     106.160622        80.994819      49.450777
# std        NaN     101.143103        88.284312      79.697598
# min        NaN       0.000000         0.000000       0.000000
# 25%        NaN      20.000000         4.000000       1.000000
# 50%        NaN      76.000000        56.000000       8.000000
# 75%        NaN     188.000000       128.000000      59.000000
# max        NaN     376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       193
# unique                           NaN         6
# top                              NaN    Africa
# ...

# %%
drinks.describe(include=['object','float64'])
# Out:
#        country  total_litres_of_pure_alcohol continent
# count      193                    193.000000       193
# unique     193                           NaN         6
# top     Kuwait                           NaN    Africa
# freq         1                           NaN        53
# mean       NaN                      4.717098       NaN
# std        NaN                      3.773298       NaN
# min        NaN                      0.000000       NaN
# 25%        NaN                      1.300000       NaN
# 50%        NaN                      4.200000       NaN
# 75%        NaN                      7.200000       NaN
# max        NaN                     14.400000       NaN

# %%
drinks.describe(include=['object'])
# Out:
#        country continent
# count      193       193
# unique     193         6
# top     Kuwait    Africa
# freq         1        53
